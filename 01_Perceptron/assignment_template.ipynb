# %% [markdown]
# # 📝 Perceptron 실습 과제
#
# **주제:** Weight · Bias · 데이터 표준화에 따른 퍼셉트론 분류 결과 비교
#
# > 본 Notebook은 과제 제출용 템플릿입니다.
# > 각 Code Cell을 직접 실행하고, 결과 분석은 Markdown Cell에 작성하세요.

# %% [markdown]
# ## 👤 학생 정보
#
# - 학번:
# - 이름:

# %% [markdown]
# ## 🎯 과제 목표
#
# - Weight 변화가 퍼셉트론의 출력에 미치는 영향을 확인한다.
# - Bias 변화에 따른 분류 결과의 차이를 확인한다.
# - StandardScaler 적용 여부에 따른 입력 데이터 변화를 비교한다.
# - Accuracy, MSE, MAE를 이용하여 결과를 분석한다.

# %% [markdown]
# # 1. Weight 변화에 따른 성능 비교
#
# 기본 Weight와 변경 Weight를 비교하세요.
#
# - 기본: `[0.5, 0.5, 0.5, 0.5]`
# - 변경: `[0.1, 0.1, 0.1, 0.1]`

# %% [markdown]
# ### ✍️ 실습 1 결과 기록
#
# | Weight | Accuracy | MSE | MAE |
# |---|---:|---:|---:|
# | `[0.5, 0.5, 0.5, 0.5]` |  <span style="color:magenta;"> 내용을 입력하세요. </span> | <span style="color:magenta;"> 내용을 입력하세요. </span> |  <span style="color:magenta;"> 내용을 입력하세요. </span> |
# | `[0.1, 0.1, 0.1, 0.1]` |  <span style="color:magenta;"> 내용을 입력하세요. </span> |  <span style="color:magenta;"> 내용을 입력하세요. </span> |  <span style="color:magenta;"> 내용을 입력하세요. </span> |
#
# ### 분석
# 아래 내용을 포함하여 **3~5문장**으로 작성하세요.
#
# 1) Weight를 변경했을 때 예측 결과가 어떻게 변했는가?
# 2) Weight 변화가 `z = X @ w + b`에 어떤 영향을 주었는가?
# 3) 결과가 달라졌거나 달라지지 않은 이유는 무엇이라고 생각하는가?
#
# ### 답안
#
# 답안 1) <span style="color:magenta;"> 내용을 입력하세요. </span>
#
# 답안 2) <span style="color:magenta;"> 내용을 입력하세요. </span>
#
# 답안 3) <span style="color:magenta;"> 내용을 입력하세요. </span>

# %% [markdown]
# # 2. Bias 변화에 따른 성능 비교
#
# 다음 두 Bias를 비교하세요.
#
# - 기본 Bias: `0.1`
# - 변경 Bias: `-0.5`

# %% [markdown]
# ### ✍️ 실습 2 결과 기록
#
# | Bias | Accuracy | MSE | MAE |
# |---:|---:|---:|---:|
# | `0.1` |  <span style="color:magenta;"> 내용을 입력하세요. </span> |  <span style="color:magenta;"> 내용을 입력하세요. </span> |  <span style="color:magenta;"> 내용을 입력하세요. </span> |
# | `-0.5` |  <span style="color:magenta;"> 내용을 입력하세요. </span> |  <span style="color:magenta;"> 내용을 입력하세요. </span> |  <span style="color:magenta;"> 내용을 입력하세요. </span> |
#
# ### 분석
# 다음 내용을 포함하여 **3~5문장**으로 작성하세요.
#
# 1) Bias를 변경했을 때 분류 결과는 어떻게 변했는가?
# 2) Bias 변화가 `z` 값에 어떤 영향을 주는가?
# 3) Weight 변화와 Bias 변화는 어떤 차이가 있는가?
#
# ### 답안
#
# 답안 1) <span style="color:magenta;"> 내용을 입력하세요. </span>
#
# 답안 2) <span style="color:magenta;"> 내용을 입력하세요. </span>
#
# 답안 3) <span style="color:magenta;"> 내용을 입력하세요. </span>

# %% [markdown]
# # 3. StandardScaler 적용 여부 비교
#
# 표준화를 적용한 경우와 적용하지 않은 경우를 비교하세요.

# %% [markdown]
# ### ✍️ 실습 3 결과 기록
#
# | 조건 | Accuracy | MSE | MAE |
# |---|---:|---:|---:|
# | StandardScaler 적용 | <span style="color:magenta;"> 내용을 입력하세요. </span> | <span style="color:magenta;"> 내용을 입력하세요. </span> | <span style="color:magenta;"> 내용을 입력하세요. </span> |
# | StandardScaler 미적용 | <span style="color:magenta;"> 내용을 입력하세요. </span> | <span style="color:magenta;"> 내용을 입력하세요. </span> | <span style="color:magenta;"> 내용을 입력하세요. </span> |
#
# ### 분석
# 다음 내용을 포함하여 **3~5문장**으로 작성하세요.
#
# 1) 표준화 전과 후의 `X` 값은 어떻게 달라졌는가?
# 2) 데이터 Scale이 퍼셉트론 계산에 영향을 줄 수 있는 이유는 무엇인가?
#
#
# ### 답안
#
# 답안 1) <span style="color:magenta;"> 내용을 입력하세요. </span>
#
# 답안 2) <span style="color:magenta;"> 내용을 입력하세요. </span>
